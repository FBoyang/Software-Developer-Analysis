# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
df = pd.read_csv("FCC_visualization.csv")

imp = preprocessing.Imputer(missing_values='None', strategy='mean', axis=0)
#extract x value and y value
y_value = df.iloc[:, -1].values
x_value = df.iloc[:, df.columns != 'IsSoftwareDev'].values
lb_make = LabelEncoder()
obj_df = df.select_dtypes(include=['object']).copy()

for i in range 
obj_df = lb_make.fit_transform(obj_df) 

x_dummies = pd.get_dummies(x_value)
logreg = LogisticRegression()
logreg.fit(x_dummies, y_value)
# Out:
#   LanguageAtHome                    MaritalStatus  \
# 0        English  married or domestic partnership
# 1        English                              NaN
# 2        English                              NaN
# 3        English                              NaN
# 4          Khmer                              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#                   CityPopulation            CountryCitizen  \
# 0  between 100,000 and 1 million  United States of America
# 1  between 100,000 and 1 million  United States of America
# 2            more than 1 million  United States of America
# ...

# %%
# Out:
#          Income   Age  HasDebt  IsEthnicMinority    LanguageAtHome  \
# 0       32000.0  28.0      1.0               0.0           English
# 1       15000.0  22.0      0.0               0.0           English
# 2       48000.0  19.0      0.0               0.0           English
# 3       43000.0  26.0      1.0               0.0           English
# 4        6000.0  20.0      1.0               1.0             Khmer
# 5       40000.0  34.0      0.0               0.0           English
# 6       32000.0  23.0      0.0               0.0  Mandarin Chinese
# 7       40000.0  35.0      0.0               1.0            Telugu
# 8       80000.0  33.0      0.0               0.0           English
# 9       80000.0  33.0      1.0               0.0           English
# 10      20000.0  57.0      1.0               0.0           English
# 11          NaN  23.0      1.0               0.0           Bengali
# 12      90000.0  47.0      1.0               0.0           English
# ...
